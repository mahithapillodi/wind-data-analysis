# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_path = '/Users/mpillodi/documents/GitHub/wind-data-analysis/csvfolder/2013_03_01_0000.csv'

# %%
df = pd.read_csv(csv_path)

# %%
print("Basic Statistics:")
print(df.describe())
# Out:
# Basic Statistics:
#        period         s1a         s1x         s1i         s1s         s2a  \
# count   144.0  144.000000  144.000000  144.000000  144.000000  144.000000
# mean    600.0   10.224012   11.891712    8.345619    0.647796   10.193815
# std       0.0    2.381134    3.124380    1.732381    0.390072    2.377584
# min     600.0    5.774900    6.188000    4.122500    0.096390    5.769310
# 25%     600.0    8.736598    9.446900    7.622375    0.257040    8.783793
# 50%     600.0    9.967865   11.053400    8.666600    0.663255    9.959980
# 75%     600.0   12.347780   14.645075    9.687875    0.922590   12.272192
# max     600.0   15.166040   19.361300   11.879600    1.702890   15.109960
#
#               s2x         s2i         s2s         s3a  ...        tii  \
# count  144.000000  144.000000  144.000000  144.000000  ...  144.00000
# mean    11.863300    8.326131    0.644927    9.724015  ...   44.43750
# std      3.109737    1.734826    0.386689    2.411603  ...    5.09589
# ...

# %%
# Data Visualization
print("Data Visualization:")
# Out:
# Data Visualization:

# %%
# Plot Wind Speeds
wind_speed_columns = ['s1a', 's1x', 's1i', 's2a', 's2x', 's2i', 's3a', 's3x', 's3i', 'p1a', 'p1x', 'p1i']
df[wind_speed_columns].plot(title='Wind Speeds')
plt.show()

# %%
# Plot Wind Directions
wind_direction_columns = ['d1a', 'd2a']
df[wind_direction_columns].plot(title='Wind Directions')
plt.show()

# %%
# Plot Air Humidity
df['h1a'].plot(title='Air Humidity')
plt.show()

# %%
# Plot Air Temperature
df['t1a'].plot(title='Air Temperature')
plt.show()

# %%
# Plot Air Pressure
df['b1a'].plot(title='Air Pressure')
plt.show()

# %%
# Plot Wind Speed at 10.0m
df['p1a'].plot(title='Wind Speed at 10.0m')
plt.show()

# %%
# Plot Temperature Internal
df['tia'].plot(title='Temperature Internal')
plt.show()

# %%
# Plot External Supply
df['vxa'].plot(title='External Supply')
plt.show()

# %%
# Plot Battery Left
df['bla'].plot(title='Battery Left')
plt.show()

# %%
# Plot Battery Right
df['bra'].plot(title='Battery Right')
plt.show()
